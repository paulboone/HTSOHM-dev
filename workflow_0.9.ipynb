# %% [markdown]
# Run this at startup...

# %%
# %cd ~/HTSOHM-2.0

# %run work_funcs.ipy
from find_rare import *
from psu_mat_mut import *

bins = 4
cutoff = 10
atomtypes = 4
strength = 0.2
numberofchildren = 500
# Out:
# /ihome/cwilmer/ark111/HTSOHM-2.0

# %% [markdown]
# # making/screening gen2

# %%
#make/screen gen2

parent = 'gen0'    #
current = 'gen1'   #
start = 500        #
length = 500       #
merged = 'tgen1'   # make sure to change this...

new = 'gen2'       # ..and this!

#pre_mut(current, start, length, parent, merged)
FindMissing(current, start, length) #check script, add initial line breaks

state = input('Continue? (y/n) :   ')

if state == 'y':
    find_rare(current, bins, cutoff) #print header
    test_plot(parent, current) # make this plot parent v. current
    
    state = input('Continue? (y/n) :   ')
    
    if state == 'y':
        mutate(merged, atomtypes, numberofchildren, strength, bins) # make sure no print
        # %mv 4atm* $new
        screen(new, length, start+length)
        print('\n...jobs submitted! Check status with `qstat`.')
        
    if state == 'n':
        print( 'rescreen materials above and try again!' )

if state == 'n':
    print( 'rescreen materials above and try again!' )
# Out:
# Missing data points
#
# methane loading :    0
# []
#
# surface area    :    0
# []
#
# void fraction   :    0
# []
#
# --------------------
#
# Continue? (y/n) :   y
#
# `Rare` materials (bin size <= 10) :
#
# ['MAT-821', 'MAT-857']
# ['MAT-503', 'MAT-694', 'MAT-762']
# ['MAT-512', 'MAT-519', 'MAT-547', 'MAT-646', 'MAT-716', 'MAT-820', 'MAT-855', 'MAT-874', 'MAT-920', 'MAT-928']
# ['MAT-574', 'MAT-576', 'MAT-582']
# ['MAT-529', 'MAT-554', 'MAT-632', 'MAT-642', 'MAT-744', 'MAT-764', 'MAT-790', 'MAT-843', 'MAT-909', 'MAT-943']
# ['MAT-619', 'MAT-649', 'MAT-690', 'MAT-863', 'MAT-912']
# ['MAT-513', 'MAT-859', 'MAT-948']
#
# --------------------
# Continue? (y/n) :   y
# making 500 materials...
# ...done!
# /ihome/cwilmer/ark111/HTSOHM-2.0/bin
# /ihome/cwilmer/ark111/HTSOHM-2.0
#
# ...jobs submitted! Check status with `qstat`.

# %% [markdown]
# ## make/screen gen3

# %%
parent = 'tgen1'    #
current = 'gen2'   #
start = 1000       #
length = 500       #
merged = 'tgen2'   # make sure to change this...

new = 'gen3'       # ..and this!

mutate_screen(parent, current, start, length, merged,
              new,bins, cutoff, atomtypes, strength,
              numberofchildren)
# Out:
# /ihome/cwilmer/ark111/HTSOHM-2.0/data
# /ihome/cwilmer/ark111/HTSOHM-2.0
# Missing data points
#
# methane loading :    0
# []
#
# surface area    :    0
# []
#
# void fraction   :    0
# []
#
# --------------------
#
# Continue? (y/n) :   y
#
# `Rare` materials (bin size <= 10) :
#
# ['MAT-1076', 'MAT-1296', 'MAT-1444']
# ['MAT-1071']
# ['MAT-1034', 'MAT-1093', 'MAT-1111', 'MAT-1146', 'MAT-1172', 'MAT-1224', 'MAT-1278', 'MAT-1318', 'MAT-1377', 'MAT-1407']
# ['MAT-1028', 'MAT-1052', 'MAT-1217', 'MAT-1275', 'MAT-1294', 'MAT-1379', 'MAT-1390', 'MAT-1477']
# ['MAT-1045', 'MAT-1089', 'MAT-1246', 'MAT-1323']
# ['MAT-1137', 'MAT-1170', 'MAT-1177', 'MAT-1348', 'MAT-1481']
# ['MAT-1449']
# ['MAT-1012', 'MAT-1051', 'MAT-1142', 'MAT-1154', 'MAT-1193', 'MAT-1231', 'MAT-1316', 'MAT-1437']
#
# --------------------
# Continue? (y/n) :   y
# making 500 materials...
# ...done!
# /ihome/cwilmer/ark111/HTSOHM-2.0/bin
# /ihome/cwilmer/ark111/HTSOHM-2.0
#
# ...jobs submitted! Check status with `qstat`.

# %% [markdown]
# ## make/screen gen4

# %%
parent = 'tgen2'    #
current = 'gen3'   #
start = 1500       #
length = 500       #
merged = 'tgen3'   # make sure to change this...

new = 'gen4'       # ..and this!

mutate_screen(parent, current, start, length, merged,
              new,bins, cutoff, atomtypes, strength,
              numberofchildren)
# Out:
# /ihome/cwilmer/ark111/HTSOHM-2.0/data
# /ihome/cwilmer/ark111/HTSOHM-2.0
# Missing data points
#
# methane loading :    0
# []
#
# surface area    :    0
# []
#
# void fraction   :    0
# []
#
# --------------------
#
# Continue? (y/n) :   y
#
# `Rare` materials (bin size <= 10) :
#
# ['MAT-1512', 'MAT-1637', 'MAT-1673', 'MAT-1744', 'MAT-1770', 'MAT-1771', 'MAT-1794', 'MAT-1864', 'MAT-1926']
# ['MAT-1788', 'MAT-1795', 'MAT-1911', 'MAT-1938']
# ['MAT-1669']
# ['MAT-1714', 'MAT-1737', 'MAT-1763', 'MAT-1830', 'MAT-1894']
# ['MAT-1569', 'MAT-1630', 'MAT-1634', 'MAT-1902', 'MAT-1921', 'MAT-1941']
# ['MAT-1977']
# ['MAT-1756', 'MAT-1840', 'MAT-1935', 'MAT-1956']
# ['MAT-1536', 'MAT-1558', 'MAT-1750', 'MAT-1782', 'MAT-1798', 'MAT-1808', 'MAT-1859', 'MAT-1861', 'MAT-1919', 'MAT-1958']
# ['MAT-1610', 'MAT-1633', 'MAT-1740', 'MAT-1806', 'MAT-1967']
# ['MAT-1502', 'MAT-1526', 'MAT-1663', 'MAT-1685', 'MAT-1793', 'MAT-1827', 'MAT-1893', 'MAT-1920']
# ...

# %%
parent = 'tgen3'    #
current = 'gen4'   #
start = 2000       #
length = 500       #
merged = 'tgen4'   # make sure to change this...

new = 'gen5'       # ..and this!

mutate_screen(parent, current, start, length, merged,
              new,bins, cutoff, atomtypes, strength,
              numberofchildren)
# Out:
# /ihome/cwilmer/ark111/HTSOHM-2.0/data
# /ihome/cwilmer/ark111/HTSOHM-2.0
# Missing data points
#
# methane loading :    0
# []
#
# surface area    :    0
# []
#
# void fraction   :    0
# []
#
# --------------------
#
# Continue? (y/n) :   y
#
# `Rare` materials (bin size <= 10) :
#
# ['MAT-2046', 'MAT-2084', 'MAT-2138', 'MAT-2186', 'MAT-2189', 'MAT-2199', 'MAT-2262', 'MAT-2426', 'MAT-2489']
# ['MAT-2091']
# ['MAT-2112', 'MAT-2276']
# ['MAT-2080', 'MAT-2225', 'MAT-2268', 'MAT-2357', 'MAT-2398', 'MAT-2421', 'MAT-2422']
# ['MAT-2266', 'MAT-2284', 'MAT-2349', 'MAT-2491']
# ['MAT-2085', 'MAT-2154', 'MAT-2240', 'MAT-2267', 'MAT-2353', 'MAT-2436', 'MAT-2487']
# ['MAT-2311', 'MAT-2457', 'MAT-2470', 'MAT-2485']
# ['MAT-2120', 'MAT-2178', 'MAT-2215', 'MAT-2228', 'MAT-2265', 'MAT-2317', 'MAT-2326', 'MAT-2368', 'MAT-2409', 'MAT-2420']
# ['MAT-2252', 'MAT-2480']
# ['MAT-2364', 'MAT-2468']
# ['MAT-2011', 'MAT-2022', 'MAT-2025', 'MAT-2152', 'MAT-2257']
# ...

# %%
parent = 'tgen4'    #
current = 'gen5'   #
start = 2500       #
length = 500       #
merged = 'tgen5'   # make sure to change this...

new = 'gen6'       # ..and this!

mutate_screen(parent, current, start, length, merged,
              new,bins, cutoff, atomtypes, strength,
              numberofchildren)
# Out:
# /ihome/cwilmer/ark111/HTSOHM-2.0/data
# /ihome/cwilmer/ark111/HTSOHM-2.0
# Missing data points
#
# methane loading :    0
# []
#
# surface area    :    0
# []
#
# void fraction   :    0
# []
#
# --------------------
#
# Continue? (y/n) :   y
#
# `Rare` materials (bin size <= 10) :
#
# ['MAT-2601']
# ['MAT-2560', 'MAT-2615', 'MAT-2732']
# ['MAT-2824', 'MAT-2924']
# ['MAT-2811']
# ['MAT-2641', 'MAT-2729', 'MAT-2797', 'MAT-2804', 'MAT-2827', 'MAT-2837', 'MAT-2865', 'MAT-2899', 'MAT-2934']
# ['MAT-2535', 'MAT-2543', 'MAT-2596', 'MAT-2648', 'MAT-2758', 'MAT-2783', 'MAT-2826', 'MAT-2963']
# ['MAT-2504', 'MAT-2508', 'MAT-2598', 'MAT-2706', 'MAT-2782', 'MAT-2798', 'MAT-2871', 'MAT-2914', 'MAT-2945', 'MAT-2996']
# ['MAT-2518', 'MAT-2541', 'MAT-2768', 'MAT-2788', 'MAT-2867']
# ['MAT-2579', 'MAT-2647', 'MAT-2660', 'MAT-2698', 'MAT-2906']
# ['MAT-2728', 'MAT-2947', 'MAT-2985']
# ...

# %%
parent = 'tgen5'    #
current = 'gen6'   #
start = 3000       #
length = 500       #
merged = 'tgen6'   # make sure to change this...

new = 'gen7'       # ..and this!

mutate_screen(parent, current, start, length, merged,
              new,bins, cutoff, atomtypes, strength,
              numberofchildren)
# Out:
# /ihome/cwilmer/ark111/HTSOHM-2.0/data
# /ihome/cwilmer/ark111/HTSOHM-2.0
# Missing data points
#
# methane loading :    0
# []
#
# surface area    :    0
# []
#
# void fraction   :    0
# []
#
# --------------------
#
# Continue? (y/n) :   y
#
# `Rare` materials (bin size <= 10) :
#
# ['MAT-3000', 'MAT-3002', 'MAT-3273', 'MAT-3428', 'MAT-3432']
# ['MAT-3138', 'MAT-3164', 'MAT-3173', 'MAT-3274', 'MAT-3319', 'MAT-3452', 'MAT-3455']
# ['MAT-3030', 'MAT-3498']
# ['MAT-3117', 'MAT-3194', 'MAT-3309', 'MAT-3399', 'MAT-3402', 'MAT-3416']
# ['MAT-3020', 'MAT-3060', 'MAT-3063', 'MAT-3187', 'MAT-3228']
# ['MAT-3062', 'MAT-3303', 'MAT-3325', 'MAT-3374', 'MAT-3463']
# ['MAT-3049']
# ['MAT-3075', 'MAT-3087', 'MAT-3105', 'MAT-3122', 'MAT-3296', 'MAT-3320']
# ['MAT-3267', 'MAT-3315']
# ['MAT-3258']
#
# --------------------
# Continue? (y/n) :   y
# making 500 materials...
# ...done!
# /ihome/cwilmer/ark111/HTSOHM-2.0/bin
# /ihome/cwilmer/ark111/HTSOHM-2.0
#
# ...

# %%
parent = 'tgen6'    #
current = 'gen7'   #
start = 3500       #
length = 500       #
merged = 'tgen7'   # make sure to change this...

new = 'gen8'       # ..and this!

mutate_screen(parent, current, start, length, merged,
              new,bins, cutoff, atomtypes, strength,
              numberofchildren)
# Out:
# /ihome/cwilmer/ark111/HTSOHM-2.0/data
# /ihome/cwilmer/ark111/HTSOHM-2.0
# Missing data points
#
# methane loading :    0
# []
#
# surface area    :    0
# []
#
# void fraction   :    0
# []
#
# --------------------
#
# Continue? (y/n) :   y
#
# `Rare` materials (bin size <= 10) :
#
# ['MAT-3527', 'MAT-3531', 'MAT-3539', 'MAT-3549', 'MAT-3554', 'MAT-3656', 'MAT-3660', 'MAT-3968', 'MAT-3983']
# ['MAT-3587', 'MAT-3740', 'MAT-3985']
# ['MAT-3572', 'MAT-3594', 'MAT-3866', 'MAT-3898', 'MAT-3914']
# ['MAT-3973']
# ['MAT-3678', 'MAT-3738', 'MAT-3839', 'MAT-3847', 'MAT-3876', 'MAT-3933', 'MAT-3935', 'MAT-3942', 'MAT-3977', 'MAT-3997']
# ['MAT-3857', 'MAT-3970']
# ['MAT-3659', 'MAT-3773', 'MAT-3776', 'MAT-3789', 'MAT-3859', 'MAT-3923', 'MAT-3934', 'MAT-3989']
# ['MAT-3595', 'MAT-3621', 'MAT-3630', 'MAT-3675', 'MAT-3780', 'MAT-3788', 'MAT-3817', 'MAT-3821']
# ['MAT-3604', 'MAT-3638', 'MAT-3662', 'MAT-3715', 'MAT-3741', 'MAT-3756', 'MAT-3871']
# ...

# %%
parent = 'tgen7'    #
current = 'gen8'   #
start = 4000       #
length = 500       #
merged = 'tgen8'   # make sure to change this...

new = 'gen9'       # ..and this!

mutate_screen(parent, current, start, length, merged,
              new,bins, cutoff, atomtypes, strength,
              numberofchildren)
# Out:
# /ihome/cwilmer/ark111/HTSOHM-2.0/data
# /ihome/cwilmer/ark111/HTSOHM-2.0
# Missing data points
#
# methane loading :    0
# []
#
# surface area    :    0
# []
#
# void fraction   :    0
# []
#
# --------------------
#
# Continue? (y/n) :   y
#
# `Rare` materials (bin size <= 10) :
#
# ['MAT-4029', 'MAT-4075', 'MAT-4118', 'MAT-4119', 'MAT-4277', 'MAT-4351', 'MAT-4358', 'MAT-4416']
# ['MAT-4043', 'MAT-4388']
# ['MAT-4072', 'MAT-4146', 'MAT-4192', 'MAT-4253', 'MAT-4259', 'MAT-4395', 'MAT-4446', 'MAT-4497']
# ['MAT-4141', 'MAT-4309', 'MAT-4413']
# ['MAT-4095', 'MAT-4386']
# ['MAT-4004', 'MAT-4066', 'MAT-4076', 'MAT-4104', 'MAT-4111', 'MAT-4246', 'MAT-4285']
# ['MAT-4053', 'MAT-4112', 'MAT-4168', 'MAT-4200', 'MAT-4265', 'MAT-4300', 'MAT-4339', 'MAT-4381', 'MAT-4399', 'MAT-4460']
# ['MAT-4018', 'MAT-4026', 'MAT-4048', 'MAT-4160', 'MAT-4191', 'MAT-4263', 'MAT-4273', 'MAT-4335', 'MAT-4421']
# ['MAT-4009', 'MAT-4252', 'MAT-4306', 'MAT-4452']
# ...

# %%
parent = 'tgen8'    #
current = 'gen9'   #
start = 4500       #
length = 500       #
merged = 'tgen9'   # make sure to change this...

new = 'gen10'       # ..and this!

mutate_screen(parent, current, start, length, merged,
              new,bins, cutoff, atomtypes, strength,
              numberofchildren)
# Out:
# /ihome/cwilmer/ark111/HTSOHM-2.0/data
# /ihome/cwilmer/ark111/HTSOHM-2.0
# Missing data points
#
# methane loading :    0
# []
#
# surface area    :    0
# []
#
# void fraction   :    0
# []
#
# --------------------
#
# Continue? (y/n) :   y
#
# `Rare` materials (bin size <= 10) :
#
# ['MAT-4591', 'MAT-4651', 'MAT-4665', 'MAT-4685', 'MAT-4700', 'MAT-4710', 'MAT-4721', 'MAT-4776', 'MAT-4916', 'MAT-4925']
# ['MAT-4631', 'MAT-4848']
# ['MAT-4674', 'MAT-4682', 'MAT-4812', 'MAT-4822', 'MAT-4862', 'MAT-4868', 'MAT-4954', 'MAT-4962']
# ['MAT-4522', 'MAT-4641', 'MAT-4759', 'MAT-4817', 'MAT-4896']
# ['MAT-4775', 'MAT-4836', 'MAT-4961']
# ['MAT-4597', 'MAT-4598', 'MAT-4626', 'MAT-4661', 'MAT-4777', 'MAT-4827', 'MAT-4904', 'MAT-4991']
# ['MAT-4577', 'MAT-4582', 'MAT-4587', 'MAT-4672', 'MAT-4792', 'MAT-4795', 'MAT-4906', 'MAT-4923']
# ['MAT-4553', 'MAT-4628', 'MAT-4707', 'MAT-4737', 'MAT-4744', 'MAT-4786', 'MAT-4788', 'MAT-4819', 'MAT-4820', 'MAT-4996']
# ...
